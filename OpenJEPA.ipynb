# %%
# !git clone https://github.com/prp-e/openjepa
# %cd openjepa
# Out:
# Cloning into 'openjepa'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 63 (delta 15), reused 63 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (63/63), 21.47 KiB | 5.37 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/openjepa

# %%
# !git pull
# Out:
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 17 (delta 6), reused 16 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (17/17), 8.26 KiB | 1.65 MiB/s, done.
# From https://github.com/prp-e/openjepa
#    d8f98e2..9c61238  main       -> origin/main
# Updating d8f98e2..9c61238
# Fast-forward
#  LICENSE                   |   8 +++
#  README.md                 | 134 ++++++++++++++++++++++++++++++++++++++++++++++
#  decode_to_svg.py          |  61 +++++++++++++++++++++
#  extensions/svg_decoder.py |  76 ++++++++++++++++++++++++++
#  extensions/svg_writer.py  |  68 +++++++++++++++++++++++
#  5 files changed, 347 insertions(+)
#  create mode 100644 LICENSE
#  create mode 100644 README.md
#  create mode 100644 decode_to_svg.py
#  create mode 100644 extensions/svg_decoder.py
#  create mode 100644 extensions/svg_writer.py

# %%
# %cd openjepa
# !python train.py --config configs/default.yaml
# Out:
# [Errno 2] No such file or directory: 'openjepa'
# /content/openjepa
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %%
# !python train.py --config configs/default.yaml --dump_latents \
    --checkpoint checkpoints/ckpt_epoch99.pt \
    --image /content/lenna.jpeg \
    --out /content/latents.pt
# Out:
# [dump_latents] saved 120 per-patch latents (dim=384) and grid positions to /content/latents.pt

# %%
import torch

d = torch.load('/content/latents.pt')
print(d.keys())
print(d['latents'].shape)
print(d['positions'].shape)
# Out:
# dict_keys(['latents', 'positions'])
# torch.Size([120, 384])
# torch.Size([120, 2])

# %%
# !python decode_to_svg.py --latents /content/latents.pt --out /content/output.svg
# Out:
# [decode_to_svg] WARNING: no --decoder_checkpoint given -- using a randomly initialized, UNTRAINED decoder. Output SVG will be structurally valid but carries no learned relationship to the input image's content.
# [decode_to_svg] saved 120 path segments to /content/output.svg
