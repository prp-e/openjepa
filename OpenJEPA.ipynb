# %%
# !git clone https://github.com/prp-e/openjepa
# %cd openjepa
# Out:
# Cloning into 'openjepa'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 204 (delta 48), reused 190 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (204/204), 613.40 KiB | 3.19 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/openjepa

# %%
# !python train.py --config configs/default_icons.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# epoch 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %%
# !python train.py --config configs/default_icons.yaml --dump_latents \
    --checkpoint checkpoints/ckpt_epoch99.pt \
    --image /content/openjepa/data/icons/08bd15d3-6394-4c8f-989a-22d38e94f9dc.jpg \
    --out /content/latents.pt
# Out:
# [dump_latents] saved 144 per-patch latents (dim=384) and grid positions to /content/latents.pt

# %%
import torch

d = torch.load('/content/latents.pt')
print(d.keys())
print(d['latents'].shape)
print(d['positions'].shape)
# Out:
# dict_keys(['latents', 'positions'])
# torch.Size([144, 384])
# torch.Size([144, 2])

# %%
# !python train_decoder.py --config configs/default_icons.yaml \
    --checkpoint checkpoints/ckpt_epoch99.pt \
    --data_root /content/openjepa/data/icons \
    --epochs 100 \
    --out /content/decoder.pt
# Out:
# [train_decoder] loading frozen target encoder from checkpoints/ckpt_epoch99.pt
# [train_decoder] 70 images found, grid_size=14, patch_size=16, embed_dim=384
# [train_decoder] epoch 0 step 10 loss 1.7248
# [train_decoder] epoch 0 step 20 loss 1.6143
# [train_decoder] epoch 0 step 30 loss 1.5941
# [train_decoder] epoch 0 step 40 loss 1.6310
# [train_decoder] epoch 0 step 50 loss 1.5342
# [train_decoder] epoch 0 step 60 loss 1.5790
# [train_decoder] epoch 0 avg_loss 1.6144
# [train_decoder] epoch 1 step 70 loss 1.5943
# [train_decoder] epoch 1 step 80 loss 1.5896
# [train_decoder] epoch 1 step 90 loss 1.5960
# [train_decoder] epoch 1 step 100 loss 1.5749
# [train_decoder] epoch 1 step 110 loss 1.5765
# [train_decoder] epoch 1 step 120 loss 1.5345
# [train_decoder] epoch 1 step 130 loss 1.5319
# [train_decoder] epoch 1 avg_loss 1.5628
# [train_decoder] epoch 2 step 140 loss 1.5344
# [train_decoder] epoch 2 step 150 loss 1.5896
# [train_decoder] epoch 2 step 160 loss 1.5542
# ...

# %%
# !python decode_to_svg.py --latents /content/latents.pt --out /content/output2.svg \
    --decoder_checkpoint /content/decoder.pt
# Out:
# [decode_to_svg] loaded trained decoder weights from /content/decoder.pt
# [decode_to_svg] saved 144 path segments to /content/output2.svg
