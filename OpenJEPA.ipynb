# %%
# !git clone https://github.com/prp-e/openjepa
# %cd openjepa
# Out:
# Cloning into 'openjepa'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 175 (delta 34), reused 167 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (175/175), 600.44 KiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/openjepa

# %%
# !python train.py --config configs/default_icons.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# epoch 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# epoch 0: 100% 2/2 [00:02<00:00,  1.39s/it, loss=0.485, lr=2.78e-6, m=0.996, wd=0.04]
# [epoch 0] avg_loss=0.4850
# [epoch 0] checkpoint saved to ./checkpoints/ckpt_epoch0.pt
# epoch 1: 100% 2/2 [00:01<00:00,  1.22it/s, loss=0.477, lr=5.56e-6, m=0.996, wd=0.04]
# [epoch 1] avg_loss=0.4769
# [epoch 1] checkpoint saved to ./checkpoints/ckpt_epoch1.pt
# epoch 2: 100% 2/2 [00:01<00:00,  1.12it/s, loss=0.465, lr=8.33e-6, m=0.996, wd=0.0401]
# [epoch 2] avg_loss=0.4649
# [epoch 2] checkpoint saved to ./checkpoints/ckpt_epoch2.pt
# epoch 3: 100% 2/2 [00:01<00:00,  1.07it/s, loss=0.446, lr=1.11e-5, m=0.996, wd=0.0401]
# [epoch 3] avg_loss=0.4464
# [epoch 3] checkpoint saved to ./checkpoints/ckpt_epoch3.pt
# epoch 4: 100% 2/2 [00:01<00:00,  1.08it/s, loss=0.429, lr=1.39e-5, m=0.996, wd=0.0402]
# [epoch 4] avg_loss=0.4289
# [epoch 4] checkpoint saved to ./checkpoints/ckpt_epoch4.pt
# epoch 5: 100% 2/2 [00:02<00:00,  1.02s/it, loss=0.412, lr=1.67e-5, m=0.996, wd=0.0403]
# [epoch 5] avg_loss=0.4121
# [epoch 5] checkpoint saved to ./checkpoints/ckpt_epoch5.pt
# epoch 6: 100% 2/2 [00:01<00:00,  1.13it/s, loss=0.383, lr=1.94e-5, m=0.996, wd=0.0404]
# [epoch 6] avg_loss=0.3826
# [epoch 6] checkpoint saved to ./checkpoints/ckpt_epoch6.pt
# epoch 7: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.375, lr=2.22e-5, m=0.996, wd=0.0406]
# [epoch 7] avg_loss=0.3747
# [epoch 7] checkpoint saved to ./checkpoints/ckpt_epoch7.pt
# epoch 8: 100% 2/2 [00:01<00:00,  1.19it/s, loss=0.362, lr=2.5e-5, m=0.996, wd=0.0407]
# [epoch 8] avg_loss=0.3621
# [epoch 8] checkpoint saved to ./checkpoints/ckpt_epoch8.pt
# epoch 9: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.346, lr=2.78e-5, m=0.996, wd=0.0409]
# [epoch 9] avg_loss=0.3459
# [epoch 9] checkpoint saved to ./checkpoints/ckpt_epoch9.pt
# epoch 10: 100% 2/2 [00:02<00:00,  1.14s/it, loss=0.345, lr=3.06e-5, m=0.996, wd=0.0411]
# [epoch 10] avg_loss=0.3454
# [epoch 10] checkpoint saved to ./checkpoints/ckpt_epoch10.pt
# epoch 11: 100% 2/2 [00:01<00:00,  1.00it/s, loss=0.346, lr=3.33e-5, m=0.996, wd=0.0413]
# [epoch 11] avg_loss=0.3457
# [epoch 11] checkpoint saved to ./checkpoints/ckpt_epoch11.pt
# epoch 12: 100% 2/2 [00:01<00:00,  1.09it/s, loss=0.319, lr=3.61e-5, m=0.996, wd=0.0415]
# [epoch 12] avg_loss=0.3188
# [epoch 12] checkpoint saved to ./checkpoints/ckpt_epoch12.pt
# epoch 13: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.334, lr=3.89e-5, m=0.996, wd=0.0418]
# [epoch 13] avg_loss=0.3340
# [epoch 13] checkpoint saved to ./checkpoints/ckpt_epoch13.pt
# epoch 14: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.317, lr=4.17e-5, m=0.996, wd=0.0421]
# [epoch 14] avg_loss=0.3171
# [epoch 14] checkpoint saved to ./checkpoints/ckpt_epoch14.pt
# epoch 15: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.308, lr=4.44e-5, m=0.996, wd=0.0424]
# [epoch 15] avg_loss=0.3077
# [epoch 15] checkpoint saved to ./checkpoints/ckpt_epoch15.pt
# epoch 16: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.3, lr=4.72e-5, m=0.996, wd=0.0427]
# [epoch 16] avg_loss=0.2996
# [epoch 16] checkpoint saved to ./checkpoints/ckpt_epoch16.pt
# epoch 17: 100% 2/2 [00:02<00:00,  1.09s/it, loss=0.292, lr=5e-5, m=0.996, wd=0.043]
# [epoch 17] avg_loss=0.2924
# [epoch 17] checkpoint saved to ./checkpoints/ckpt_epoch17.pt
# epoch 18: 100% 2/2 [00:01<00:00,  1.07it/s, loss=0.288, lr=5.28e-5, m=0.996, wd=0.0434]
# [epoch 18] avg_loss=0.2882
# [epoch 18] checkpoint saved to ./checkpoints/ckpt_epoch18.pt
# epoch 19: 100% 2/2 [00:02<00:00,  1.01s/it, loss=0.279, lr=5.56e-5, m=0.996, wd=0.0438]
# [epoch 19] avg_loss=0.2793
# [epoch 19] checkpoint saved to ./checkpoints/ckpt_epoch19.pt
# epoch 20: 100% 2/2 [00:02<00:00,  1.03s/it, loss=0.32, lr=5.83e-5, m=0.996, wd=0.0441]
# [epoch 20] avg_loss=0.3198
# [epoch 20] checkpoint saved to ./checkpoints/ckpt_epoch20.pt
# epoch 21: 100% 2/2 [00:02<00:00,  1.06s/it, loss=0.287, lr=6.11e-5, m=0.996, wd=0.0446]
# [epoch 21] avg_loss=0.2875
# [epoch 21] checkpoint saved to ./checkpoints/ckpt_epoch21.pt
# epoch 22: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.291, lr=6.39e-5, m=0.996, wd=0.045]
# [epoch 22] avg_loss=0.2908
# [epoch 22] checkpoint saved to ./checkpoints/ckpt_epoch22.pt
# epoch 23: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.305, lr=6.67e-5, m=0.996, wd=0.0454]
# [epoch 23] avg_loss=0.3053
# [epoch 23] checkpoint saved to ./checkpoints/ckpt_epoch23.pt
# epoch 24: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.264, lr=6.94e-5, m=0.996, wd=0.0459]
# [epoch 24] avg_loss=0.2638
# [epoch 24] checkpoint saved to ./checkpoints/ckpt_epoch24.pt
# epoch 25: 100% 2/2 [00:02<00:00,  1.01s/it, loss=0.223, lr=7.22e-5, m=0.996, wd=0.0464]
# [epoch 25] avg_loss=0.2229
# [epoch 25] checkpoint saved to ./checkpoints/ckpt_epoch25.pt
# epoch 26: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.235, lr=7.5e-5, m=0.996, wd=0.0469]
# [epoch 26] avg_loss=0.2351
# [epoch 26] checkpoint saved to ./checkpoints/ckpt_epoch26.pt
# epoch 27: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.273, lr=7.78e-5, m=0.996, wd=0.0474]
# [epoch 27] avg_loss=0.2730
# [epoch 27] checkpoint saved to ./checkpoints/ckpt_epoch27.pt
# epoch 28: 100% 2/2 [00:02<00:00,  1.11s/it, loss=0.232, lr=8.06e-5, m=0.996, wd=0.048]
# [epoch 28] avg_loss=0.2319
# [epoch 28] checkpoint saved to ./checkpoints/ckpt_epoch28.pt
# epoch 29: 100% 2/2 [00:01<00:00,  1.13it/s, loss=0.239, lr=8.33e-5, m=0.996, wd=0.0485]
# [epoch 29] avg_loss=0.2391
# [epoch 29] checkpoint saved to ./checkpoints/ckpt_epoch29.pt
# epoch 30: 100% 2/2 [00:02<00:00,  1.12s/it, loss=0.264, lr=8.61e-5, m=0.996, wd=0.0491]
# [epoch 30] avg_loss=0.2645
# [epoch 30] checkpoint saved to ./checkpoints/ckpt_epoch30.pt
# epoch 31: 100% 2/2 [00:01<00:00,  1.06it/s, loss=0.222, lr=8.89e-5, m=0.996, wd=0.0497]
# [epoch 31] avg_loss=0.2222
# [epoch 31] checkpoint saved to ./checkpoints/ckpt_epoch31.pt
# epoch 32: 100% 2/2 [00:01<00:00,  1.07it/s, loss=0.216, lr=9.17e-5, m=0.996, wd=0.0504]
# [epoch 32] avg_loss=0.2155
# [epoch 32] checkpoint saved to ./checkpoints/ckpt_epoch32.pt
# epoch 33: 100% 2/2 [00:01<00:00,  1.16it/s, loss=0.255, lr=9.44e-5, m=0.996, wd=0.051]
# [epoch 33] avg_loss=0.2551
# [epoch 33] checkpoint saved to ./checkpoints/ckpt_epoch33.pt
# epoch 34: 100% 2/2 [00:02<00:00,  1.01s/it, loss=0.225, lr=9.72e-5, m=0.996, wd=0.0517]
# [epoch 34] avg_loss=0.2254
# [epoch 34] checkpoint saved to ./checkpoints/ckpt_epoch34.pt
# epoch 35: 100% 2/2 [00:02<00:00,  1.11s/it, loss=0.248, lr=0.0001, m=0.996, wd=0.0523]
# [epoch 35] avg_loss=0.2476
# [epoch 35] checkpoint saved to ./checkpoints/ckpt_epoch35.pt
# epoch 36: 100% 2/2 [00:02<00:00,  1.39s/it, loss=0.233, lr=0.000103, m=0.996, wd=0.053]
# [epoch 36] avg_loss=0.2328
# [epoch 36] checkpoint saved to ./checkpoints/ckpt_epoch36.pt
# epoch 37: 100% 2/2 [00:02<00:00,  1.07s/it, loss=0.225, lr=0.000106, m=0.997, wd=0.0537]
# [epoch 37] avg_loss=0.2248
# [epoch 37] checkpoint saved to ./checkpoints/ckpt_epoch37.pt
# epoch 38: 100% 2/2 [00:01<00:00,  1.06it/s, loss=0.242, lr=0.000108, m=0.997, wd=0.0545]
# [epoch 38] avg_loss=0.2416
# [epoch 38] checkpoint saved to ./checkpoints/ckpt_epoch38.pt
# epoch 39: 100% 2/2 [00:01<00:00,  1.13it/s, loss=0.179, lr=0.000111, m=0.997, wd=0.0552]
# [epoch 39] avg_loss=0.1794
# [epoch 39] checkpoint saved to ./checkpoints/ckpt_epoch39.pt
# epoch 40: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.218, lr=0.000114, m=0.997, wd=0.056]
# [epoch 40] avg_loss=0.2184
# [epoch 40] checkpoint saved to ./checkpoints/ckpt_epoch40.pt
# epoch 41: 100% 2/2 [00:02<00:00,  1.01s/it, loss=0.23, lr=0.000117, m=0.997, wd=0.0568]
# [epoch 41] avg_loss=0.2298
# [epoch 41] checkpoint saved to ./checkpoints/ckpt_epoch41.pt
# epoch 42: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.222, lr=0.000119, m=0.997, wd=0.0576]
# [epoch 42] avg_loss=0.2217
# [epoch 42] checkpoint saved to ./checkpoints/ckpt_epoch42.pt
# epoch 43: 100% 2/2 [00:01<00:00,  1.17it/s, loss=0.221, lr=0.000122, m=0.997, wd=0.0584]
# [epoch 43] avg_loss=0.2209
# [epoch 43] checkpoint saved to ./checkpoints/ckpt_epoch43.pt
# epoch 44: 100% 2/2 [00:02<00:00,  1.13s/it, loss=0.249, lr=0.000125, m=0.997, wd=0.0593]
# [epoch 44] avg_loss=0.2490
# [epoch 44] checkpoint saved to ./checkpoints/ckpt_epoch44.pt
# epoch 45: 100% 2/2 [00:02<00:00,  1.17s/it, loss=0.234, lr=0.000125, m=0.997, wd=0.0601]
# [epoch 45] avg_loss=0.2337
# [epoch 45] checkpoint saved to ./checkpoints/ckpt_epoch45.pt
# epoch 46: 100% 2/2 [00:02<00:00,  1.00s/it, loss=0.23, lr=0.000125, m=0.997, wd=0.061]
# [epoch 46] avg_loss=0.2304
# [epoch 46] checkpoint saved to ./checkpoints/ckpt_epoch46.pt
# epoch 47: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.202, lr=0.000125, m=0.997, wd=0.0619]
# [epoch 47] avg_loss=0.2021
# [epoch 47] checkpoint saved to ./checkpoints/ckpt_epoch47.pt
# epoch 48: 100% 2/2 [00:01<00:00,  1.07it/s, loss=0.194, lr=0.000125, m=0.997, wd=0.0628]
# [epoch 48] avg_loss=0.1944
# [epoch 48] checkpoint saved to ./checkpoints/ckpt_epoch48.pt
# epoch 49: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.205, lr=0.000125, m=0.997, wd=0.0637]
# [epoch 49] avg_loss=0.2051
# [epoch 49] checkpoint saved to ./checkpoints/ckpt_epoch49.pt
# epoch 50: 100% 2/2 [00:01<00:00,  1.12it/s, loss=0.196, lr=0.000125, m=0.997, wd=0.0647]
# [epoch 50] avg_loss=0.1961
# [epoch 50] checkpoint saved to ./checkpoints/ckpt_epoch50.pt
# epoch 51: 100% 2/2 [00:01<00:00,  1.07it/s, loss=0.199, lr=0.000125, m=0.997, wd=0.0656]
# [epoch 51] avg_loss=0.1989
# [epoch 51] checkpoint saved to ./checkpoints/ckpt_epoch51.pt
# epoch 52: 100% 2/2 [00:01<00:00,  1.13it/s, loss=0.233, lr=0.000125, m=0.997, wd=0.0666]
# [epoch 52] avg_loss=0.2335
# [epoch 52] checkpoint saved to ./checkpoints/ckpt_epoch52.pt
# epoch 53: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.189, lr=0.000125, m=0.997, wd=0.0676]
# [epoch 53] avg_loss=0.1892
# [epoch 53] checkpoint saved to ./checkpoints/ckpt_epoch53.pt
# epoch 54: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.154, lr=0.000125, m=0.997, wd=0.0686]
# [epoch 54] avg_loss=0.1544
# [epoch 54] checkpoint saved to ./checkpoints/ckpt_epoch54.pt
# epoch 55: 100% 2/2 [00:01<00:00,  1.00it/s, loss=0.226, lr=0.000125, m=0.997, wd=0.0697]
# [epoch 55] avg_loss=0.2258
# [epoch 55] checkpoint saved to ./checkpoints/ckpt_epoch55.pt
# epoch 56: 100% 2/2 [00:01<00:00,  1.06it/s, loss=0.208, lr=0.000124, m=0.997, wd=0.0707]
# [epoch 56] avg_loss=0.2077
# [epoch 56] checkpoint saved to ./checkpoints/ckpt_epoch56.pt
# epoch 57: 100% 2/2 [00:02<00:00,  1.11s/it, loss=0.182, lr=0.000124, m=0.997, wd=0.0718]
# [epoch 57] avg_loss=0.1820
# [epoch 57] checkpoint saved to ./checkpoints/ckpt_epoch57.pt
# epoch 58: 100% 2/2 [00:01<00:00,  1.00it/s, loss=0.221, lr=0.000124, m=0.997, wd=0.0728]
# [epoch 58] avg_loss=0.2210
# [epoch 58] checkpoint saved to ./checkpoints/ckpt_epoch58.pt
# epoch 59: 100% 2/2 [00:02<00:00,  1.07s/it, loss=0.201, lr=0.000124, m=0.997, wd=0.0739]
# [epoch 59] avg_loss=0.2009
# [epoch 59] checkpoint saved to ./checkpoints/ckpt_epoch59.pt
# epoch 60: 100% 2/2 [00:01<00:00,  1.08it/s, loss=0.165, lr=0.000124, m=0.997, wd=0.075]
# [epoch 60] avg_loss=0.1648
# [epoch 60] checkpoint saved to ./checkpoints/ckpt_epoch60.pt
# epoch 61: 100% 2/2 [00:01<00:00,  1.00it/s, loss=0.156, lr=0.000124, m=0.997, wd=0.0762]
# [epoch 61] avg_loss=0.1560
# [epoch 61] checkpoint saved to ./checkpoints/ckpt_epoch61.pt
# epoch 62: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.219, lr=0.000124, m=0.997, wd=0.0773]
# [epoch 62] avg_loss=0.2191
# [epoch 62] checkpoint saved to ./checkpoints/ckpt_epoch62.pt
# epoch 63: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.223, lr=0.000123, m=0.997, wd=0.0785]
# [epoch 63] avg_loss=0.2227
# [epoch 63] checkpoint saved to ./checkpoints/ckpt_epoch63.pt
# epoch 64: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.202, lr=0.000123, m=0.997, wd=0.0796]
# [epoch 64] avg_loss=0.2023
# [epoch 64] checkpoint saved to ./checkpoints/ckpt_epoch64.pt
# epoch 65: 100% 2/2 [00:02<00:00,  1.07s/it, loss=0.2, lr=0.000123, m=0.997, wd=0.0808]
# [epoch 65] avg_loss=0.1996
# [epoch 65] checkpoint saved to ./checkpoints/ckpt_epoch65.pt
# epoch 66: 100% 2/2 [00:01<00:00,  1.05it/s, loss=0.196, lr=0.000123, m=0.997, wd=0.082]
# [epoch 66] avg_loss=0.1960
# [epoch 66] checkpoint saved to ./checkpoints/ckpt_epoch66.pt
# epoch 67: 100% 2/2 [00:02<00:00,  1.10s/it, loss=0.179, lr=0.000123, m=0.997, wd=0.0833]
# [epoch 67] avg_loss=0.1793
# [epoch 67] checkpoint saved to ./checkpoints/ckpt_epoch67.pt
# epoch 68: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.191, lr=0.000123, m=0.997, wd=0.0845]
# [epoch 68] avg_loss=0.1913
# [epoch 68] checkpoint saved to ./checkpoints/ckpt_epoch68.pt
# epoch 69: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.189, lr=0.000122, m=0.997, wd=0.0858]
# [epoch 69] avg_loss=0.1891
# [epoch 69] checkpoint saved to ./checkpoints/ckpt_epoch69.pt
# epoch 70: 100% 2/2 [00:02<00:00,  1.00s/it, loss=0.213, lr=0.000122, m=0.997, wd=0.087]
# [epoch 70] avg_loss=0.2134
# [epoch 70] checkpoint saved to ./checkpoints/ckpt_epoch70.pt
# epoch 71: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.227, lr=0.000122, m=0.997, wd=0.0883]
# [epoch 71] avg_loss=0.2273
# [epoch 71] checkpoint saved to ./checkpoints/ckpt_epoch71.pt
# epoch 72: 100% 2/2 [00:02<00:00,  1.02s/it, loss=0.168, lr=0.000122, m=0.997, wd=0.0896]
# [epoch 72] avg_loss=0.1678
# [epoch 72] checkpoint saved to ./checkpoints/ckpt_epoch72.pt
# epoch 73: 100% 2/2 [00:01<00:00,  1.15it/s, loss=0.168, lr=0.000121, m=0.997, wd=0.0909]
# [epoch 73] avg_loss=0.1681
# [epoch 73] checkpoint saved to ./checkpoints/ckpt_epoch73.pt
# epoch 74: 100% 2/2 [00:02<00:00,  1.12s/it, loss=0.233, lr=0.000121, m=0.997, wd=0.0922]
# [epoch 74] avg_loss=0.2329
# [epoch 74] checkpoint saved to ./checkpoints/ckpt_epoch74.pt
# epoch 75: 100% 2/2 [00:01<00:00,  1.06it/s, loss=0.177, lr=0.000121, m=0.997, wd=0.0936]
# [epoch 75] avg_loss=0.1766
# [epoch 75] checkpoint saved to ./checkpoints/ckpt_epoch75.pt
# epoch 76: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.212, lr=0.000121, m=0.997, wd=0.0949]
# [epoch 76] avg_loss=0.2123
# [epoch 76] checkpoint saved to ./checkpoints/ckpt_epoch76.pt
# epoch 77: 100% 2/2 [00:02<00:00,  1.02s/it, loss=0.241, lr=0.00012, m=0.997, wd=0.0963]
# [epoch 77] avg_loss=0.2412
# [epoch 77] checkpoint saved to ./checkpoints/ckpt_epoch77.pt
# epoch 78: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.204, lr=0.00012, m=0.997, wd=0.0977]
# [epoch 78] avg_loss=0.2042
# [epoch 78] checkpoint saved to ./checkpoints/ckpt_epoch78.pt
# epoch 79: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.196, lr=0.00012, m=0.997, wd=0.099]
# [epoch 79] avg_loss=0.1959
# [epoch 79] checkpoint saved to ./checkpoints/ckpt_epoch79.pt
# epoch 80: 100% 2/2 [00:02<00:00,  1.11s/it, loss=0.219, lr=0.000119, m=0.997, wd=0.1]
# [epoch 80] avg_loss=0.2192
# [epoch 80] checkpoint saved to ./checkpoints/ckpt_epoch80.pt
# epoch 81: 100% 2/2 [00:01<00:00,  1.17it/s, loss=0.191, lr=0.000119, m=0.997, wd=0.102]
# [epoch 81] avg_loss=0.1905
# [epoch 81] checkpoint saved to ./checkpoints/ckpt_epoch81.pt
# epoch 82: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.175, lr=0.000119, m=0.997, wd=0.103]
# [epoch 82] avg_loss=0.1754
# [epoch 82] checkpoint saved to ./checkpoints/ckpt_epoch82.pt
# epoch 83: 100% 2/2 [00:02<00:00,  1.12s/it, loss=0.187, lr=0.000118, m=0.997, wd=0.105]
# [epoch 83] avg_loss=0.1872
# [epoch 83] checkpoint saved to ./checkpoints/ckpt_epoch83.pt
# epoch 84: 100% 2/2 [00:02<00:00,  1.04s/it, loss=0.208, lr=0.000118, m=0.997, wd=0.106]
# [epoch 84] avg_loss=0.2082
# [epoch 84] checkpoint saved to ./checkpoints/ckpt_epoch84.pt
# epoch 85: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.22, lr=0.000118, m=0.997, wd=0.108]
# [epoch 85] avg_loss=0.2199
# [epoch 85] checkpoint saved to ./checkpoints/ckpt_epoch85.pt
# epoch 86: 100% 2/2 [00:01<00:00,  1.17it/s, loss=0.174, lr=0.000117, m=0.997, wd=0.109]
# [epoch 86] avg_loss=0.1740
# [epoch 86] checkpoint saved to ./checkpoints/ckpt_epoch86.pt
# epoch 87: 100% 2/2 [00:02<00:00,  1.08s/it, loss=0.16, lr=0.000117, m=0.997, wd=0.111]
# [epoch 87] avg_loss=0.1600
# [epoch 87] checkpoint saved to ./checkpoints/ckpt_epoch87.pt
# epoch 88: 100% 2/2 [00:01<00:00,  1.13it/s, loss=0.169, lr=0.000117, m=0.997, wd=0.112]
# [epoch 88] avg_loss=0.1695
# [epoch 88] checkpoint saved to ./checkpoints/ckpt_epoch88.pt
# epoch 89: 100% 2/2 [00:02<00:00,  1.12s/it, loss=0.202, lr=0.000116, m=0.997, wd=0.114]
# [epoch 89] avg_loss=0.2016
# [epoch 89] checkpoint saved to ./checkpoints/ckpt_epoch89.pt
# epoch 90: 100% 2/2 [00:02<00:00,  1.10s/it, loss=0.176, lr=0.000116, m=0.997, wd=0.115]
# [epoch 90] avg_loss=0.1763
# [epoch 90] checkpoint saved to ./checkpoints/ckpt_epoch90.pt
# epoch 91: 100% 2/2 [00:01<00:00,  1.02it/s, loss=0.163, lr=0.000116, m=0.997, wd=0.117]
# [epoch 91] avg_loss=0.1633
# [epoch 91] checkpoint saved to ./checkpoints/ckpt_epoch91.pt
# epoch 92: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.144, lr=0.000115, m=0.997, wd=0.118]
# [epoch 92] avg_loss=0.1438
# [epoch 92] checkpoint saved to ./checkpoints/ckpt_epoch92.pt
# epoch 93: 100% 2/2 [00:02<00:00,  1.10s/it, loss=0.141, lr=0.000115, m=0.997, wd=0.12]
# [epoch 93] avg_loss=0.1413
# [epoch 93] checkpoint saved to ./checkpoints/ckpt_epoch93.pt
# epoch 94: 100% 2/2 [00:01<00:00,  1.05it/s, loss=0.18, lr=0.000114, m=0.997, wd=0.121]
# [epoch 94] avg_loss=0.1800
# [epoch 94] checkpoint saved to ./checkpoints/ckpt_epoch94.pt
# epoch 95: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.185, lr=0.000114, m=0.997, wd=0.123]
# [epoch 95] avg_loss=0.1848
# [epoch 95] checkpoint saved to ./checkpoints/ckpt_epoch95.pt
# epoch 96: 100% 2/2 [00:02<00:00,  1.09s/it, loss=0.151, lr=0.000113, m=0.997, wd=0.125]
# [epoch 96] avg_loss=0.1513
# [epoch 96] checkpoint saved to ./checkpoints/ckpt_epoch96.pt
# epoch 97: 100% 2/2 [00:01<00:00,  1.00it/s, loss=0.173, lr=0.000113, m=0.997, wd=0.126]
# [epoch 97] avg_loss=0.1731
# [epoch 97] checkpoint saved to ./checkpoints/ckpt_epoch97.pt
# epoch 98: 100% 2/2 [00:01<00:00,  1.24it/s, loss=0.151, lr=0.000113, m=0.997, wd=0.128]
# [epoch 98] avg_loss=0.1513
# [epoch 98] checkpoint saved to ./checkpoints/ckpt_epoch98.pt
# epoch 99: 100% 2/2 [00:02<00:00,  1.16s/it, loss=0.18, lr=0.000112, m=0.997, wd=0.129]
# [epoch 99] avg_loss=0.1804
# [epoch 99] checkpoint saved to ./checkpoints/ckpt_epoch99.pt
# epoch 100: 100% 2/2 [00:02<00:00,  1.19s/it, loss=0.18, lr=0.000112, m=0.997, wd=0.131]
# [epoch 100] avg_loss=0.1801
# [epoch 100] checkpoint saved to ./checkpoints/ckpt_epoch100.pt
# epoch 101: 100% 2/2 [00:03<00:00,  1.80s/it, loss=0.212, lr=0.000111, m=0.997, wd=0.133]
# [epoch 101] avg_loss=0.2116
# [epoch 101] checkpoint saved to ./checkpoints/ckpt_epoch101.pt
# epoch 102: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.189, lr=0.000111, m=0.997, wd=0.134]
# [epoch 102] avg_loss=0.1888
# [epoch 102] checkpoint saved to ./checkpoints/ckpt_epoch102.pt
# epoch 103: 100% 2/2 [00:02<00:00,  1.01s/it, loss=0.14, lr=0.00011, m=0.997, wd=0.136]
# [epoch 103] avg_loss=0.1398
# [epoch 103] checkpoint saved to ./checkpoints/ckpt_epoch103.pt
# epoch 104: 100% 2/2 [00:02<00:00,  1.03s/it, loss=0.201, lr=0.00011, m=0.997, wd=0.138]
# [epoch 104] avg_loss=0.2007
# [epoch 104] checkpoint saved to ./checkpoints/ckpt_epoch104.pt
# epoch 105: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.162, lr=0.000109, m=0.997, wd=0.139]
# [epoch 105] avg_loss=0.1621
# [epoch 105] checkpoint saved to ./checkpoints/ckpt_epoch105.pt
# epoch 106: 100% 2/2 [00:01<00:00,  1.03it/s, loss=0.129, lr=0.000109, m=0.997, wd=0.141]
# [epoch 106] avg_loss=0.1294
# [epoch 106] checkpoint saved to ./checkpoints/ckpt_epoch106.pt
# epoch 107: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.15, lr=0.000108, m=0.997, wd=0.143]
# [epoch 107] avg_loss=0.1496
# [epoch 107] checkpoint saved to ./checkpoints/ckpt_epoch107.pt
# epoch 108: 100% 2/2 [00:02<00:00,  1.12s/it, loss=0.205, lr=0.000108, m=0.997, wd=0.145]
# [epoch 108] avg_loss=0.2046
# [epoch 108] checkpoint saved to ./checkpoints/ckpt_epoch108.pt
# epoch 109: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.159, lr=0.000107, m=0.997, wd=0.146]
# [epoch 109] avg_loss=0.1593
# [epoch 109] checkpoint saved to ./checkpoints/ckpt_epoch109.pt
# epoch 110: 100% 2/2 [00:01<00:00,  1.05it/s, loss=0.189, lr=0.000107, m=0.997, wd=0.148]
# [epoch 110] avg_loss=0.1892
# [epoch 110] checkpoint saved to ./checkpoints/ckpt_epoch110.pt
# epoch 111: 100% 2/2 [00:02<00:00,  1.00s/it, loss=0.212, lr=0.000106, m=0.997, wd=0.15]
# [epoch 111] avg_loss=0.2124
# [epoch 111] checkpoint saved to ./checkpoints/ckpt_epoch111.pt
# epoch 112: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.134, lr=0.000106, m=0.998, wd=0.151]
# [epoch 112] avg_loss=0.1342
# [epoch 112] checkpoint saved to ./checkpoints/ckpt_epoch112.pt
# epoch 113: 100% 2/2 [00:01<00:00,  1.10it/s, loss=0.147, lr=0.000105, m=0.998, wd=0.153]
# [epoch 113] avg_loss=0.1470
# [epoch 113] checkpoint saved to ./checkpoints/ckpt_epoch113.pt
# epoch 114: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.168, lr=0.000105, m=0.998, wd=0.155]
# [epoch 114] avg_loss=0.1684
# [epoch 114] checkpoint saved to ./checkpoints/ckpt_epoch114.pt
# epoch 115: 100% 2/2 [00:01<00:00,  1.17it/s, loss=0.153, lr=0.000104, m=0.998, wd=0.157]
# [epoch 115] avg_loss=0.1535
# [epoch 115] checkpoint saved to ./checkpoints/ckpt_epoch115.pt
# epoch 116: 100% 2/2 [00:02<00:00,  1.10s/it, loss=0.171, lr=0.000103, m=0.998, wd=0.158]
# [epoch 116] avg_loss=0.1713
# [epoch 116] checkpoint saved to ./checkpoints/ckpt_epoch116.pt
# epoch 117: 100% 2/2 [00:01<00:00,  1.04it/s, loss=0.16, lr=0.000103, m=0.998, wd=0.16]
# [epoch 117] avg_loss=0.1600
# [epoch 117] checkpoint saved to ./checkpoints/ckpt_epoch117.pt
# epoch 118: 100% 2/2 [00:02<00:00,  1.05s/it, loss=0.162, lr=0.000102, m=0.998, wd=0.162]
# [epoch 118] avg_loss=0.1620
# [epoch 118] checkpoint saved to ./checkpoints/ckpt_epoch118.pt
# epoch 119: 100% 2/2 [00:01<00:00,  1.12it/s, loss=0.175, lr=0.000102, m=0.998, wd=0.164]
# [epoch 119] avg_loss=0.1752
# [epoch 119] checkpoint saved to ./checkpoints/ckpt_epoch119.pt
# epoch 120: 100% 2/2 [00:02<00:00,  1.25s/it, loss=0.199, lr=0.000101, m=0.998, wd=0.166]
# [epoch 120] avg_loss=0.1988
# [epoch 120] checkpoint saved to ./checkpoints/ckpt_epoch120.pt
# epoch 121: 100% 2/2 [00:02<00:00,  1.10s/it, loss=0.14, lr=0.000101, m=0.998, wd=0.167]
# [epoch 121] avg_loss=0.1396
# [epoch 121] checkpoint saved to ./checkpoints/ckpt_epoch121.pt
# epoch 122: 100% 2/2 [00:02<00:00,  1.08s/it, loss=0.177, lr=9.99e-5, m=0.998, wd=0.169]
# [epoch 122] avg_loss=0.1767
# [epoch 122] checkpoint saved to ./checkpoints/ckpt_epoch122.pt
# epoch 123: 100% 2/2 [00:01<00:00,  1.08it/s, loss=0.182, lr=9.93e-5, m=0.998, wd=0.171]
# [epoch 123] avg_loss=0.1824
# [epoch 123] checkpoint saved to ./checkpoints/ckpt_epoch123.pt
# epoch 124: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.153, lr=9.87e-5, m=0.998, wd=0.173]
# [epoch 124] avg_loss=0.1526
# [epoch 124] checkpoint saved to ./checkpoints/ckpt_epoch124.pt
# epoch 125: 100% 2/2 [00:02<00:00,  1.02s/it, loss=0.14, lr=9.81e-5, m=0.998, wd=0.175]
# [epoch 125] avg_loss=0.1398
# [epoch 125] checkpoint saved to ./checkpoints/ckpt_epoch125.pt
# epoch 126: 100% 2/2 [00:02<00:00,  1.22s/it, loss=0.173, lr=9.75e-5, m=0.998, wd=0.177]
# [epoch 126] avg_loss=0.1731
# [epoch 126] checkpoint saved to ./checkpoints/ckpt_epoch126.pt
# epoch 127: 100% 2/2 [00:02<00:00,  1.09s/it, loss=0.145, lr=9.69e-5, m=0.998, wd=0.178]
# [epoch 127] avg_loss=0.1445
# [epoch 127] checkpoint saved to ./checkpoints/ckpt_epoch127.pt
# epoch 128: 100% 2/2 [00:02<00:00,  1.21s/it, loss=0.19, lr=9.63e-5, m=0.998, wd=0.18]
# [epoch 128] avg_loss=0.1905
# [epoch 128] checkpoint saved to ./checkpoints/ckpt_epoch128.pt
# epoch 129: 100% 2/2 [00:02<00:00,  1.21s/it, loss=0.159, lr=9.56e-5, m=0.998, wd=0.182]
# [epoch 129] avg_loss=0.1591
# [epoch 129] checkpoint saved to ./checkpoints/ckpt_epoch129.pt
# epoch 130: 100% 2/2 [00:02<00:00,  1.06s/it, loss=0.141, lr=9.5e-5, m=0.998, wd=0.184]
# [epoch 130] avg_loss=0.1411
# [epoch 130] checkpoint saved to ./checkpoints/ckpt_epoch130.pt
# epoch 131: 100% 2/2 [00:02<00:00,  1.00s/it, loss=0.147, lr=9.44e-5, m=0.998, wd=0.186]
# [epoch 131] avg_loss=0.1469
# [epoch 131] checkpoint saved to ./checkpoints/ckpt_epoch131.pt
# epoch 132: 100% 2/2 [00:01<00:00,  1.17it/s, loss=0.146, lr=9.37e-5, m=0.998, wd=0.188]
# [epoch 132] avg_loss=0.1462
# [epoch 132] checkpoint saved to ./checkpoints/ckpt_epoch132.pt
# epoch 133: 100% 2/2 [00:01<00:00,  1.01it/s, loss=0.159, lr=9.31e-5, m=0.998, wd=0.189]
# [epoch 133] avg_loss=0.1590
# [epoch 133] checkpoint saved to ./checkpoints/ckpt_epoch133.pt
# epoch 134: 100% 2/2 [00:01<00:00,  1.06it/s, loss=0.168, lr=9.24e-5, m=0.998, wd=0.191]
# [epoch 134] avg_loss=0.1681
# [epoch 134] checkpoint saved to ./checkpoints/ckpt_epoch134.pt
# epoch 135: 100% 2/2 [00:01<00:00,  1.09it/s, loss=0.173, lr=9.18e-5, m=0.998, wd=0.193]
# [epoch 135] avg_loss=0.1728
# [epoch 135] checkpoint saved to ./checkpoints/ckpt_epoch135.pt
# epoch 136: 100% 2/2 [00:01<00:00,  1.09it/s, loss=0.174, lr=9.11e-5, m=0.998, wd=0.195]
# [epoch 136] avg_loss=0.1743
# [epoch 136] checkpoint saved to ./checkpoints/ckpt_epoch136.pt
# epoch 137: 100% 2/2 [00:01<00:00,  1.11it/s, loss=0.173, lr=9.04e-5, m=0.998, wd=0.197]
# [epoch 137] avg_loss=0.1727
# [epoch 137] checkpoint saved to ./checkpoints/ckpt_epoch137.pt
# epoch 138:   0% 0/2 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1524, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1483, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1310, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/openjepa/train.py", line 223, in <module>
#     main()
#   File "/content/openjepa/train.py", line 219, in main
#     train(cfg)
#   File "/content/openjepa/train.py", line 133, in train
#     stats = train_one_epoch(
#             ^^^^^^^^^^^^^^^^
#   File "/content/openjepa/engine/train_one_epoch.py", line 40, in train_one_epoch
#     for images, context_mask, target_masks in pbar:
#                                               ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1302, in close
#     self.display(pos=0)
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1495, in display
#     self.sp(self.__str__() if msg is None else msg)
#             ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1150, in __str__
#     def __str__(self):
#
# KeyboardInterrupt

# %%
# !python train.py --config configs/default.yaml --dump_latents \
    --checkpoint checkpoints/ckpt_epoch137.pt \
    --image /content/pineapple.jpg \
    --out /content/latents.pt
# Out:
# [dump_latents] saved 120 per-patch latents (dim=384) and grid positions to /content/latents.pt

# %%
import torch

d = torch.load('/content/latents.pt')
print(d.keys())
print(d['latents'].shape)
print(d['positions'].shape)
# Out:
# dict_keys(['latents', 'positions'])
# torch.Size([120, 384])
# torch.Size([120, 2])
